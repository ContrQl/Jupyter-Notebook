# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_theme()

seaborn_demo = 'seaborn_demo.xlsx'
biomarkers = pd.read_excel(seaborn_demo, sheet_name=None)
print(biomarkers.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       7 seaborn_demo = 'seaborn_demo.xlsx'
#       8 biomarkers = pd.read_excel(seaborn_demo, sheet_name=None)
# ----> 9 print(biomarkers.head())
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
from numpy import random
x = random.normal(loc=1, scale=2, size=(2,3)) # loc = Mean; scale = SD

print(x)
# Out:
# [[ 3.6937977   0.05570789  0.18152789]
#  [ 1.49683154  2.59618734 -2.85968266]]

# %%
sns.displot(

# %%
from numpy import random

sns.displot(random.normal(size=5000))

plt.show()
